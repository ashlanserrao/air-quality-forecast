# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading the CSV

# %%
df_raw = pd.read_csv(r'./delhi_pm25_features.csv')

# %%
df_raw.shape
# Out:
# (80709, 21)

# %%
df_raw.head()
# Out:
#    pm25_hourly  n_obs_hour  latitude  longitude  \
# 0        297.0         NaN  28.63576   77.22445
# 1        307.0         NaN  28.63576   77.22445
# 2        309.0         NaN  28.63576   77.22445
# 3        315.0         NaN  28.63576   77.22445
# 4        330.0         NaN  28.63576   77.22445
#
#                                            _raw_item  temperature  \
# 0  {'coordinates': None, 'coverage': {'datetimeFr...          NaN
# 1  {'coordinates': None, 'coverage': {'datetimeFr...          NaN
# 2  {'coordinates': None, 'coverage': {'datetimeFr...          NaN
# 3  {'coordinates': None, 'coverage': {'datetimeFr...          NaN
# 4  {'coordinates': None, 'coverage': {'datetimeFr...          NaN
#
#    relative_humidity  wind_speed  hour  sin_hour  ...  weekday  pm25_lag_1h  \
# 0                NaN         NaN    19 -0.965926  ...        2          NaN
# 1                NaN         NaN    20 -0.866025  ...        2        297.0
# 2                NaN         NaN    21 -0.707107  ...        2        307.0
# 3                NaN         NaN    22 -0.500000  ...        2        309.0
# 4                NaN         NaN    23 -0.258819  ...        2        315.0
#
#    pm25_lag_3h  pm25_lag_24h  pm25_roll_mean_24h  location_id       lat  \
# 0          NaN           NaN          297.000000         8118  28.63576
# 1          NaN           NaN          302.000000         8118  28.63576
# 2          NaN           NaN          304.333333         8118  28.63576
# 3        297.0           NaN          307.000000         8118  28.63576
# 4        307.0           NaN          311.600000         8118  28.63576
#
#         lon  location_id_code  is_holiday
# 0  77.22445                 0       False
# 1  77.22445                 0       False
# 2  77.22445                 0       False
# 3  77.22445                 0       False
# 4  77.22445                 0       False
#
# [5 rows x 21 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80709 entries, 0 to 80708
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pm25_hourly         75899 non-null  float64
#  1   n_obs_hour          0 non-null      float64
#  2   latitude            80709 non-null  float64
#  3   longitude           80709 non-null  float64
#  4   _raw_item           80709 non-null  object
#  5   temperature         0 non-null      float64
#  6   relative_humidity   0 non-null      float64
#  7   wind_speed          0 non-null      float64
#  8   hour                80709 non-null  int64
#  9   sin_hour            80709 non-null  float64
#  10  cos_hour            80709 non-null  float64
#  11  weekday             80709 non-null  int64
#  12  pm25_lag_1h         75898 non-null  float64
#  13  pm25_lag_3h         75896 non-null  float64
#  14  pm25_lag_24h        75875 non-null  float64
#  15  pm25_roll_mean_24h  78852 non-null  float64
#  16  location_id         80709 non-null  int64
#  17  lat                 80709 non-null  float64
#  18  lon                 80709 non-null  float64
#  19  location_id_code    80709 non-null  int64
#  20  is_holiday          80709 non-null  bool
# dtypes: bool(1), float64(15), int64(4), object(1)
# memory usage: 12.4+ MB

# %%
#Number of unique values in dataframe
df_raw.nunique()
# Out:
# pm25_hourly            1313
# n_obs_hour                0
# latitude                  1
# longitude                 1
# _raw_item             80709
# temperature               0
# relative_humidity         0
# wind_speed                0
# hour                     24
# sin_hour                 21
# cos_hour                 22
# weekday                   7
# pm25_lag_1h            1313
# pm25_lag_3h            1313
# pm25_lag_24h           1313
# pm25_roll_mean_24h    20855
# location_id               1
# lat                       1
# lon                       1
# location_id_code          1
# is_holiday                2
# dtype: int64

# %%
#Null values in dataset
df_raw.isnull().sum()
# Out:
# pm25_hourly            4810
# n_obs_hour            80709
# latitude                  0
# longitude                 0
# _raw_item                 0
# temperature           80709
# relative_humidity     80709
# wind_speed            80709
# hour                      0
# sin_hour                  0
# cos_hour                  0
# weekday                   0
# pm25_lag_1h            4811
# pm25_lag_3h            4813
# pm25_lag_24h           4834
# pm25_roll_mean_24h     1857
# location_id               0
# lat                       0
# lon                       0
# location_id_code          0
# is_holiday                0
# dtype: int64

# %%
# Percentage of null values
(df_raw.isnull().sum()/(len(df_raw)))*100
# Out:
# pm25_hourly             5.959682
# n_obs_hour            100.000000
# latitude                0.000000
# longitude               0.000000
# _raw_item               0.000000
# temperature           100.000000
# relative_humidity     100.000000
# wind_speed            100.000000
# hour                    0.000000
# sin_hour                0.000000
# cos_hour                0.000000
# weekday                 0.000000
# pm25_lag_1h             5.960921
# pm25_lag_3h             5.963399
# pm25_lag_24h            5.989419
# pm25_roll_mean_24h      2.300859
# location_id             0.000000
# lat                     0.000000
# lon                     0.000000
# location_id_code        0.000000
# is_holiday              0.000000
# dtype: float64

# %%
#Statistics
df_raw.describe().T
# Out:
#                       count         mean           std         min  \
# pm25_hourly         75899.0    73.427509  2.369581e+02  -999.00000
# n_obs_hour              0.0          NaN           NaN         NaN
# latitude            80709.0    28.635760  3.552736e-15    28.63576
# longitude           80709.0    77.224450  0.000000e+00    77.22445
# temperature             0.0          NaN           NaN         NaN
# relative_humidity       0.0          NaN           NaN         NaN
# wind_speed              0.0          NaN           NaN         NaN
# hour                80709.0    11.512149  6.924664e+00     0.00000
# sin_hour            80709.0    -0.002836  7.057750e-01    -1.00000
# cos_hour            80709.0    -0.000555  7.084389e-01    -1.00000
# weekday             80709.0     2.988638  2.003202e+00     0.00000
# pm25_lag_1h         75898.0    73.428292  2.369595e+02  -999.00000
# pm25_lag_3h         75896.0    73.429713  2.369625e+02  -999.00000
# pm25_lag_24h        75875.0    73.443565  2.369938e+02  -999.00000
# pm25_roll_mean_24h  78852.0    61.094761  2.065673e+02  -999.00000
# location_id         80709.0  8118.000000  0.000000e+00  8118.00000
# lat                 80709.0    28.635760  3.552736e-15    28.63576
# lon                 80709.0    77.224450  0.000000e+00    77.22445
# location_id_code    80709.0     0.000000  0.000000e+00     0.00000
#
#                             25%           50%          75%         max
# pm25_hourly           33.000000  6.400000e+01   138.000000  1990.00000
# n_obs_hour                  NaN           NaN          NaN         NaN
# latitude              28.635760  2.863576e+01    28.635760    28.63576
# longitude             77.224450  7.722445e+01    77.224450    77.22445
# temperature                 NaN           NaN          NaN         NaN
# relative_humidity           NaN           NaN          NaN         NaN
# wind_speed                  NaN           NaN          NaN         NaN
# hour                   6.000000  1.200000e+01    18.000000    23.00000
# sin_hour              -0.707107  0.000000e+00     0.707107     1.00000
# cos_hour              -0.707107 -1.836970e-16     0.707107     1.00000
# weekday                1.000000  3.000000e+00     5.000000     6.00000
# pm25_lag_1h           33.000000  6.400000e+01   138.000000  1990.00000
# pm25_lag_3h           33.000000  6.400000e+01   138.000000  1990.00000
# pm25_lag_24h          33.000000  6.400000e+01   138.000000  1990.00000
# pm25_roll_mean_24h    29.958333  6.491667e+01   137.500000  1990.00000
# location_id         8118.000000  8.118000e+03  8118.000000  8118.00000
# lat                   28.635760  2.863576e+01    28.635760    28.63576
# lon                   77.224450  7.722445e+01    77.224450    77.22445
# location_id_code       0.000000  0.000000e+00     0.000000     0.00000

# %%
# Seperating Categorical and numerical columns
cat_cols = df_raw.select_dtypes(include = ['object']).columns
num_cols = df_raw.select_dtypes(include = np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['_raw_item'], dtype='object')
# Numerical Variables:
# ['pm25_hourly', 'n_obs_hour', 'latitude', 'longitude', 'temperature', 'relative_humidity', 'wind_speed', 'hour', 'sin_hour', 'cos_hour', 'weekday', 'pm25_lag_1h', 'pm25_lag_3h', 'pm25_lag_24h', 'pm25_roll_mean_24h', 'location_id', 'lat', 'lon', 'location_id_code']
